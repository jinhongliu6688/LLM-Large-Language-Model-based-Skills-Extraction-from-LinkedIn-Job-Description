# %%
import pandas as pd
import spacy
from tqdm import tqdm

# %%
df = pd.read_csv('all_gpt_labelled_data.csv')
df.head()
# Out:
#                                                  job  \
# 0  SummaryThe Database Developer is part of the C...
# 1  Come Work with Us!At RBC, our culture is deepl...
# 2  Job IntroductionYou’ll be in an exciting, stim...
# 3  The Information Technology (IT) Department aim...
# 4  Are you an Analytics professional experienced ...
#
#                                               skills  \
# 0  ['C#', '.Net', 'database performance', 'C#', '...
# 1  ['data science', 'RBC Elements', 'Statistical'...
# 2  ['identity', 'SQL', 'NoSQL', 'Javascript', 'Gi...
# 3  ['Cybersecurity', 'design', 'Cybersecurity', '...
# 4  ['Analytics', 'Insurance', 'Strategy', 'Analyt...
#
#                                                  url
# 0  https://www.linkedin.com/jobs/view/database-de...
# 1  https://ca.linkedin.com/jobs/view/data-scienti...
# 2  https://uk.linkedin.com/jobs/view/software-eng...
# 3  https://ca.linkedin.com/jobs/view/director-of-...
# 4  https://www.linkedin.com/jobs/view/manager-ai-...

# %% [markdown]
# ## Getting filtered skills

# %%
files = ['Data/skill_ashwin_filtered.txt',
        'Data/skill_jaskirat_filtered.txt',
        'Data/skill_sai_filtered.txt',
        'Data/skill_jinhong_filtered.txt',
        'Data/skill_rakesh_filtered.txt']


skill_set = set()
for file in files:
    file = open(file)
    skill_set.update(file.read().split('\n'))
len(skill_set)
# Out:
# 1912

# %%
skill_set
# Out:
# {'statistics',
#  'ajax',
#  'visual concepts',
#  'virtualitics',
#  'hci',
#  'techinsights',
#  'sas',
#  'multivariate regression',
#  'network security',
#  'tactical',
#  'security software',
#  'c++',
#  'pl',
#  'erp',
#  'analytical ability',
#  'predictive analytics',
#  'product management',
#  'matrix-management',
#  'linux',
#  'github prs',
#  'iphone',
#  'web platform',
#  'os installations',
#  'mat',
#  'troubleshooting',
#  'reporting',
#  'devops',
#  'data quality',
#  'photoshop',
#  'remote access',
#  'monitoring',
#  'digital forensics',
#  'lp analyst',
#  'sql/ssis developer',
#  'flux',
#  'sip',
#  'mac',
#  'software engineering',
#  'data manipulation',
#  'ux/ui',
#  'apache camel',
#  'drupal',
#  'mern technologies',
#  'problem identification',
#  'sfmc',
#  'transportation',
#  'database design',
#  'leadership principles',
#  'strategic growth',
#  'biomedical nlp',
#  'critical thinking',
#  'power',
#  'keras',
#  'implementation',
#  'backend engineer',
#  'prototypes',
#  'flex',
#  'salary',
#  'transit',
#  'collaborative spirit',
#  'database mysql',
#  'power platform',
#  'video engineering',
#  'probabilistic',
#  'emr',
#  'docker',
#  'statistical modeling',
#  'gl',
#  'jpl hysds',
#  'vc',
#  'satellite data',
#  'waterfall',
#  'uart',
#  'gs',
#  'clinical knowledge',
#  'tegria',
#  'isla',
#  'devops engineer',
#  'bi tools',
#  'automation scripting',
#  'nodejs',
#  'statistical methods',
#  'process automation',
#  'cloud native',
#  'analytical mindset',
#  'security studies',
#  'ald',
#  'framework (c#)',
#  'remote working',
#  'aws well-',
#  'methodical',
#  'action oriented',
#  'it infrastructure',
#  'chatbot development',
#  'ussorted',
#  'fore',
#  'zero',
#  'risk analysis',
#  'nuxt',
#  'threat detection',
#  'financial wellbeing',
#  'def',
#  'integration',
#  'cross-dep',
#  'goodrx',
#  'user analysis',
#  'security operations',
#  'plsql',
#  'credit scoring',
#  'vue js',
#  'voice over',
#  'nosql',
#  'oracle rac',
#  'product',
#  'contextual',
#  'selective service',
#  'ml scientist/engineer',
#  'trunk',
#  'datastores',
#  'chemistry',
#  'cloud big',
#  'enterprise',
#  'rb:dba',
#  'cognitive engineering',
#  'optimization methods',
#  'battery',
#  'website design',
#  'detection',
#  'financial products',
#  '3d design',
#  'open source',
#  'demonware',
#  'wifi',
#  'triage',
#  'deep learning',
#  'digital design',
#  'software',
#  'restful apis',
#  'data analytics',
#  'online',
#  'collegial',
#  'scala/java',
#  'esg',
#  'sql dba',
#  'openai',
#  'graph db',
#  'hr',
#  'privacy',
#  'r&d',
#  'computerized databases',
#  'ms office',
#  'saas',
#  'js (expressjs)',
#  'seo',
#  'systems engineering',
#  'rdb',
#  'image processing',
#  'research',
#  'linux administration',
#  'fullstack',
#  'administrative support',
#  'adga',
#  'streaming',
#  'rsoc',
#  'snowflake',
#  'power autom',
#  'agile',
#  'team building',
#  'server administration',
#  'strategy',
#  'database monitoring',
#  'secure',
#  'business reporting',
#  'google docs',
#  'es',
#  'incident handling',
#  'marketplace design',
#  'data solutions',
#  'data analysis',
#  'scss',
#  'bert',
#  'firewall',
#  'meta',
#  'cluster',
#  'website development',
#  'fraud detection',
#  'multimedia',
#  'sota',
#  'airflow',
#  'dataiku',
#  'pandora',
#  'scikit-learn',
#  'product development',
#  'brp products',
#  'solution architects',
#  'cortex™',
#  'industrial engineering',
#  'macos',
#  'ip protection',
#  'cross-dis',
#  'ui design',
#  'code correctness',
#  'flexibility',
#  'iat ii',
#  'analytical modeling',
#  'troubleshoot',
#  'customer focused',
#  'ssis',
#  'tcp/',
#  'windows emb',
#  'df',
#  'hipaa',
#  'vision insurance',
#  'dlp',
#  'back end',
#  'nimble',
#  'database application(s)',
#  'cloud data',
#  'terraform',
#  'ms windows',
#  'kl',
#  'phd',
#  'microsoft .netframework',
#  'digital twin',
#  'splunk',
#  'collections',
#  'powershell/az',
#  'database administration',
#  'python',
#  'about usgrid',
#  'entrepreneurship',
#  'data wrangling',
#  'cdk',
#  'streamforge',
#  'operating system',
#  'api development',
#  'bitbucket',
#  'compute',
#  'political science',
#  'mining',
#  'gradle',
#  'cloud architecture',
#  'hopstack',
#  'security analyst',
#  'financial data',
#  'ottawa east',
#  'commun',
#  'pytor',
#  'artifactory',
#  'conversational ai',
#  'altis',
#  'lint',
#  'db',
#  'software installation',
#  'shopper marketing',
#  'telemedicine',
#  'ce certification',
#  'game technology',
#  'sunroom',
#  'network infrastructure',
#  'lockheed',
#  'intercom',
#  'it applications',
#  'powerbi',
#  'eurofins scientific',
#  'continuous monitoring',
#  'junior information',
#  'interpersonal',
#  'machine learning',
#  'meriplex communications',
#  'configuration management',
#  'parsing',
#  'dev-ops',
#  'data management',
#  'financial services',
#  'digital programs',
#  'eurofins',
#  'wealth management',
#  'model interpret',
#  'mdr',
#  'career assistance',
#  'gs-13',
#  'caf',
#  'cal',
#  'tools',
#  'design patterns',
#  'data scientist',
#  'cyber',
#  'cassandra',
#  'security monitoring',
#  'amazon azure',
#  'bash shell',
#  'programmatic',
#  'tls',
#  'sql queries\\',
#  'cyber security',
#  'digital technologies',
#  'corporate security',
#  'object detection/',
#  'growth mindset',
#  'math',
#  'autopilot',
#  'sql',
#  'safety analyst',
#  'spe_accommodation',
#  'aws expressjs',
#  'nlp/ml',
#  'cm',
#  'java script',
#  'application development',
#  'click therapeutics',
#  'lockton',
#  'database engineering',
#  'rack',
#  'tensorflow',
#  'digital marketing',
#  'advertising technology',
#  'web frameworks',
#  'microsoft.netframework',
#  'mathematics',
#  'database management',
#  'data-led',
#  'design principles',
#  'digital strategies',
#  'vs studio',
#  'stack',
#  'cellular data',
#  'shapeless',
#  'safari',
#  'propensity modeling',
#  'data-driven infrastructure',
#  'microservices',
#  'evc',
#  'cyber essentials',
#  'it recruiter',
#  'part developer',
#  'next.js',
#  'service',
#  'product analytics',
#  'fda submission',
#  'ml methods',
#  'unix-based command-line',
#  'collaborative data',
#  'certifications',
#  'lambda',
#  'mydubble',
#  'documents verifying',
#  'asp.net core',
#  'unit tests',
#  'dq',
#  'sunwing',
#  'creative thinker',
#  'ambulatory',
#  'npm',
#  'windows server',
#  'robotics stack',
#  'snapdragon ride',
#  'research engineer',
#  'customer support',
#  'distributed computing',
#  'lateral thinking',
#  'computational linguistics',
#  'network',
#  'npr 7150.2',
#  'software platform',
#  'mern stack',
#  'etl',
#  'sangoma',
#  'arista networks',
#  'software development',
#  'j2ee',
#  'operating systems',
#  'cookies',
#  'ccpa',
#  'protocols',
#  'msc.',
#  'full stack',
#  'front-end development',
#  'serverless',
#  'hpc',
#  'cybercoders',
#  'transformers',
#  'es6',
#  'vivosense',
#  'people skills',
#  'zscaler',
#  'joro',
#  'cold restore',
#  'data models',
#  'color vision',
#  'speech recognition',
#  'evaluation',
#  'functional programming',
#  'tuning',
#  'elastic search',
#  'clinical operations',
#  'interpersonal skills',
#  'stats',
#  'biomedic',
#  'cv',
#  'security controls',
#  'big data',
#  'enterprise java',
#  'bi',
#  'google analytics',
#  'causal inference',
#  'semantic machines',
#  'linux/unix',
#  'data structures',
#  'aws govcloud-native',
#  'user testing',
#  'redux',
#  'ruby',
#  'vue',
#  'college student',
#  'atlanta',
#  'it-',
#  'poweredge',
#  'text classification',
#  'sangoma technologies',
#  'figma',
#  'ml ops',
#  'ui animations',
#  'cybersecurity analyst',
#  'cellular/wire',
#  'data-driven algorithms',
#  'entity framework',
#  'desktop',
#  'signal processing',
#  'multim',
#  'spark',
#  'generation',
#  'amex flex',
#  'expressjs',
#  'grad students',
#  'conversationally interactive',
#  'java 8',
#  'oltp',
#  'database support',
#  'source control',
#  'configurations',
#  'biochemistry',
#  'task management',
#  'cloud devops',
#  'natural history',
#  'osint',
#  'business automation',
#  'functional front-end',
#  'visualization',
#  'ml/nlp',
#  'system administration',
#  'software application',
#  'site operation',
#  'azure cloud',
#  'incident',
#  'icloud',
#  'powerapps',
#  'software factory',
#  'peace corps/vis',
#  'ui level',
#  'postgre',
#  'backend',
#  'elk',
#  'robotic',
#  'node.js',
#  'systems management',
#  'iac',
#  'node +',
#  'technical',
#  'nlp',
#  'siri',
#  'debugging/profiling',
#  'cloudflare',
#  'd&i',
#  'linear algebra',
#  'application engineer',
#  'passionate',
#  'azure ad',
#  'gitlab',
#  'nextiva',
#  'cordova',
#  'solutions design',
#  'impact data',
#  'globalization',
#  'knowledge graphs',
#  'apis',
#  'angular',
#  'confluence',
#  'kubernetes',
#  'software engineer',
#  'autodesk',
#  'microservice',
#  'college degree',
#  'cloud saves',
#  'review incoming',
#  'rest',
#  'dom manipulation',
#  'tcp/udp',
#  'pinterest',
#  'webpack',
#  'security',
#  'operationalising strategy',
#  'contract manufacturing',
#  'elasticsearch',
#  'gcp cloud',
#  'ci/cd',
#  '.net',
#  'ui/ux design',
#  'applied mathematics',
#  'cloud administration',
#  'semantic recognition',
#  'model maintenance',
#  'saltstack',
#  'full-stack solution',
#  'web apis',
#  'database engineer',
#  'sql agent',
#  'r&',
#  'shell',
#  'omnisys',
#  'open-source',
#  'technology development',
#  'directviz solutions',
#  'techie',
#  'ci',
#  'el',
#  'opengl',
#  'pl/sql',
#  'ter',
#  'system performance',
#  'mcse',
#  'fast growing',
#  'software professionals',
#  'mathematical programming',
#  'etl performance',
#  'database performance',
#  'microsoft development',
#  'activemq',
#  'aeronautics',
#  'negotiation',
#  'technology services',
#  'asp.net',
#  'visionary',
#  'azure sql',
#  'nhl',
#  'systems analysis',
#  'vanilla js',
#  'dev10',
#  'microsoft sql',
#  'system architecture',
#  'microsoft entra',
#  'threat analysis',
#  'playstation',
#  'statistical',
#  'fullstack developer',
#  'hive/hado',
#  'agile methodology',
#  'data access',
#  'digital signal',
#  'digital experiences',
#  'containerization',
#  'administration',
#  'documenting',
#  'frontend engineer',
#  'peloton',
#  'scientific computing',
#  'mpp',
#  'excellent communicator',
#  'rpa',
#  'css3',
#  'computer programming',
#  'bubble',
#  'triaging',
#  'other',
#  'software technology',
#  'cpat',
#  'svn',
#  'windows',
#  'wifi location',
#  'audit',
#  'pl-sql',
#  'laravel',
#  '.netplatform modernisation',
#  'software testing',
#  'security+',
#  'freight',
#  'configuration',
#  'spring',
#  'apache',
#  'kotlin/java',
#  'data ware',
#  'tpl',
#  'graph',
#  '3d games',
#  'iot sticker',
#  'itunes',
#  'risk control',
#  'numerical/language libraries',
#  'malware analysis',
#  'cohort browser',
#  'digital products',
#  'sql server',
#  't-sql',
#  'digital transformation',
#  'leadership',
#  'der',
#  'front-end',
#  'payments engineering',
#  'execution excellence',
#  'senior software',
#  'cellular software',
#  'cloud computing',
#  'asset enrollment',
#  'cvs health',
#  'vistrada',
#  'angular js',
#  'data strategy',
#  'twitter',
#  'web developer',
#  'fullstack engineer',
#  'openshift',
#  'impact-driven',
#  'unity',
#  'continuous integration',
#  'ibm watson',
#  'restful',
#  'virtual ser',
#  'contracting/proc',
#  'intrusion analysis',
#  'documentation',
#  'cloud providers',
#  'sqlexpert',
#  'gender identity',
#  'soho',
#  'technology solutions',
#  'iiot',
#  'pandas',
#  'biomedical',
#  'creative strategy',
#  'html 5',
#  '3d geometry',
#  'gps',
#  'computer engineering',
#  'sonarqube',
#  'thena',
#  'vuejs',
#  'programming languages',
#  'cloud-based platform',
#  'clarity ai',
#  'entrepreneurial leadership',
#  'international business',
#  'flinks',
#  'html5',
#  'aclu',
#  'algorithms engineering',
#  'computational linguist',
#  'react native',
#  'design-driven',
#  'electrical engineering',
#  'business acumen',
#  'softwareone',
#  'css grid',
#  'security clearance',
#  'datalex',
#  'grc area',
#  'azure database',
#  'hcltech',
#  'redis',
#  'back-end engineering',
#  'retail industry',
#  'agile development',
#  'development tools',
#  'animation',
#  'cloud+',
#  'scalability',
#  'cle',
#  'infrastructure services',
#  'os',
#  'database querying',
#  'glue',
#  'nextjs',
#  'linear',
#  'compassionate',
#  'bash',
#  'audit reports',
#  'digital therapeutics',
#  'qa testing',
#  'government',
#  'sdlc/pm',
#  'jsp',
#  'canada',
#  'webbtree',
#  'cloud apps',
#  'distance vision',
#  'mongodb',
#  'strategic advisory',
#  'capacity management',
#  'healthcare systems',
#  'iaas',
#  'whiteboarding',
#  'natilus',
#  'technical operations',
#  'pietra',
#  'cloud services',
#  'batteries',
#  'data cleansing',
#  'ssl/tls decryption',
#  'postgresql',
#  'cloud research',
#  'cyber threat',
#  'scraping',
#  'information retrieval',
#  'data',
#  'explainable ai',
#  'webgl',
#  'azure adf',
#  'alerts',
#  'automl',
#  'embedded software',
#  'spark ml',
#  'data warehousing',
#  'adaptability',
#  'treeline',
#  'text analytics',
#  'tsql',
#  'financial efficiency',
#  'application skills',
#  'ai/machine learning',
#  'video analysis',
#  'analytical thinker',
#  'functions',
#  'critical',
#  'robot framework',
#  'dl',
#  'optical products',
#  'client satisfaction',
#  'risk management',
#  'pr',
#  'entrepreneurial',
#  'ms sql',
#  'laptop security',
#  'soft skills',
#  'executive',
#  'advanced analytics',
#  'cosmos',
#  'server technologies',
#  'network certification',
#  'datab',
#  'iam',
#  'backend development',
#  'image science',
#  'front end',
#  'cloud implementations',
#  'information security',
#  'tubi',
#  'website architecture',
#  'process transformation',
#  'sustain.life',
#  'osaro',
#  'enterprise architect',
#  'classdojo',
#  'klarity',
#  'nlp/',
#  'tarion',
#  'laptop backup',
#  'storage management',
#  'privacy notice',
#  'cartrawler',
#  'curious',
#  'safety manager',
#  'academic partners',
#  'mntn',
#  'apache spark',
#  'data science/',
#  'commercial',
#  'scripting',
#  'azure data',
#  'heroku',
#  'zcca',
#  'specialist',
#  'responsibilities',
#  'artificial intelligence',
#  'cloud functions',
#  'iso27001',
#  'vs code',
#  'business strategy',
#  'database architecture',
#  'web api',
#  'java',
#  'haskell',
#  'technology',
#  'business professionals',
#  '3d knitting',
#  'network ids',
#  'ubuntu/linux',
#  'database administrator',
#  'optel',
#  'cyber defense',
#  'resmed',
#  'server',
#  'code-',
#  'currently',
#  'database technologies',
#  'react-based web',
#  'contract development',
#  'pyspark',
#  'telesign',
#  'birdies',
#  'carbon chain',
#  'ut',
#  'infrastructure/sre/dev',
#  'up',
#  'td securities',
#  'business',
#  'vitality',
#  'dolby',
#  'oracle cloud',
#  'web services',
#  'dataflow',
#  'engineering',
#  'data pipeline',
#  'innovation',
#  'cloud leader',
#  'etl/',
#  's&e',
#  'culture-focused',
#  'c#',
#  'escal',
#  'penetration testing',
#  'vulnerability scanning',
#  'flat',
#  'usb',
#  'verneek',
#  'virgin orbit',
#  'cyber strategy',
#  'orm',
#  'script',
#  'testing procedures',
#  'healthcare standards',
#  'opensky',
#  'pulsedata',
#  'problem-solving',
#  'mobile commerce',
#  'pension employer',
#  'senior director',
#  'lua',
#  'software prototyping',
#  'continuous delivery',
#  'telecom technology',
#  'accounting',
#  'beeline',
#  'spark mllib',
#  'ios',
#  'clojure',
#  'relational databases',
#  'business judgment',
#  'tact',
#  'mila',
#  'system engineering',
#  'intermediate',
#  'banking',
#  'warp',
#  'cloud-',
#  'data driven',
#  'air transat',
#  'creativity',
#  'ans',
#  'cooperation',
#  'bs',
#  'management consulting',
#  'database',
#  'rust',
#  'chinese',
#  'epigenomic',
#  'junit',
#  'sfox',
#  'middleware/api engineering',
#  'cemco',
#  'workforce intelligence',
#  'variance',
#  'bachelors',
#  'spatial',
#  'data stack',
#  'ms word',
#  'commercial real',
#  'mentorshiplead',
#  'virtualization',
#  'data integration',
#  'bpss',
#  'rest apis',
#  'component',
#  'logs',
#  'database developer',
#  'next',
#  'azure environments',
#  'verification automation',
#  'web front',
#  'gcp/',
#  'grammarly',
#  'hard worker',
#  'l2/l3 protocols',
#  'dod',
#  'backend engineering',
#  'mlops',
#  'ui layout',
#  'technology risk',
#  'angular/typescript',
#  'swift',
#  'survey development',
#  'oracle databases',
#  'remote or',
#  'global talent',
#  'scalable',
#  'ux',
#  'business solutions',
#  'enterprise working',
#  'legislation',
#  'insights',
#  'dcips',
#  'continuous improvement',
#  'ccna',
#  'build core',
#  'iis',
#  'inscribe',
#  'embedded linux',
#  'information support',
#  'apache airflow',
#  'gym membership',
#  'tarion infrastructure',
#  'bi/',
#  'blend360',
#  'aws sagemaker',
#  'frontend developer',
#  'ibm',
#  'oracle dba',
#  'illust',
#  'b2b',
#  'decision tree',
#  'autodesk software',
#  'supportive',
#  'collaborative',
#  'flask',
#  'ag',
#  'insider threat',
#  'ixl learning',
#  '3d engines',
#  'oraclems',
#  'scripting language(s)',
#  'data protection',
#  'aws dev',
#  'arcmap',
#  'realitykit',
#  'jsoc',
#  'people analytics',
#  'microsoft products',
#  'machine vision',
#  'supply chain',
#  'career',
#  'academic excellence',
#  'git',
#  'blockchain technology',
#  'healthcare consulting',
#  'mongo db',
#  'care models',
#  'dmi',
#  'ict',
#  'container',
#  'intrav',
#  'data profiler',
#  'augmented reality',
#  'delivery',
#  'directory services',
#  'diversity',
#  'defence',
#  'landing pages',
#  'system engineer',
#  'cloud-based payments',
#  'pl/s',
#  'microsoft power',
#  'javascript/',
#  'insurtech',
#  'mathematical modeling',
#  'supplier intelligence',
#  'web app',
#  'cobit/',
#  'sqletl',
#  'ci/',
#  'debug',
#  'databricks',
#  'reinforcement learning',
#  'clearly',
#  'eager',
#  'azuredevops',
#  'additional information',
#  'siriusx',
#  'front-end developer',
#  'wordpress',
#  'xml',
#  'social science',
#  'cloud',
#  ...}

# %% [markdown]
# ### filtering skills

# %%
def filter_skills(skills):
    skill_list = [i.strip()[1:-1] for i in skills[1:-1].split(',')]
    return ', '.join([i for i in set(skill_list) if i.lower() in skill_set])

filter_skills(df['skills'][0])
# Out:
# 'teamwork, Project management, SQL, CEMCO, C#, database performance, close vision, T-SQL, distance vision, LLC, .Net, .NET'

# %%
df['filtered_skills'] = df['skills'].apply(filter_skills)
df[['skills','filtered_skills']].sample(10)
# Out:
#                                                  skills  \
# 920   ['JavaScript', 'React', 'HTML5', 'CSS3', 'Java...
# 787   ['Mobile apps', 'cloud-based', 'data mining', ...
# 893                      ['DBA', 'Oracle', 'PL', 'Ksh']
# 1039  ['Strategic advisory', 'leadership', 'tailored...
# 1125  ['QA', 'REST APIs', 'microservices', 'C#', 'Go...
# 1117  ['national strength', 'RPA', 'Power Automate',...
# 794   ['Healthcare', 'billing', 'administrative over...
# 1163  ['Cloud Engineer', 'AWS', 'Azure', 'Cloud Serv...
# 1106  ['AWS', 'Terraform', 'scripting', 'Jenkins', '...
# 609               ['Apple', 'Apple', 'user experience']
#
#                                         filtered_skills
# 920                      HTML5, React, CSS3, JavaScript
# 787   data mining, cloud-based, Typesc, statistical ...
# 893                                PL, Oracle, DBA, Ksh
# 1039  Jr. DBA, Sql, telecom technology, Strategic ad...
# 1125             C#, REST APIs, Java, microservices, Go
# 1117          NLP, Power Automate, Microsoft Power, RPA
# 794            data science, Docker, PostgreSQL, Python
# 1163  Cloud Budget, Cloud Administration, Azure, bus...
# 1106  JavaScript, Terraform, IT, SonarQube, Angular,...
# 609

# %%
df.head()
# Out:
#                                                  job  \
# 0  SummaryThe Database Developer is part of the C...
# 1  Come Work with Us!At RBC, our culture is deepl...
# 2  Job IntroductionYou’ll be in an exciting, stim...
# 3  The Information Technology (IT) Department aim...
# 4  Are you an Analytics professional experienced ...
#
#                                               skills  \
# 0  ['C#', '.Net', 'database performance', 'C#', '...
# 1  ['data science', 'RBC Elements', 'Statistical'...
# 2  ['identity', 'SQL', 'NoSQL', 'Javascript', 'Gi...
# 3  ['Cybersecurity', 'design', 'Cybersecurity', '...
# 4  ['Analytics', 'Insurance', 'Strategy', 'Analyt...
#
#                                                  url  \
# 0  https://www.linkedin.com/jobs/view/database-de...
# 1  https://ca.linkedin.com/jobs/view/data-scienti...
# 2  https://uk.linkedin.com/jobs/view/software-eng...
# 3  https://ca.linkedin.com/jobs/view/director-of-...
# 4  https://www.linkedin.com/jobs/view/manager-ai-...
#
#                                      filtered_skills
# 0  teamwork, Project management, SQL, CEMCO, C#, ...
# 1  Data Science, Statistical, data science, Mathe...
# 2               Javascript, NoSQL, SQL, Git, Jenkins
# 3                    design, ISO27001, Cybersecurity
# 4  AI, machine learning, fleet, Consulting, Analy...

# %%
df.to_csv('Data/GPT-3_skills_filtered_data.csv')

# %% [markdown]
# ### Splitting job_descriptions into smaller segments to avoid token limit violation for our models

# %%
nlp = spacy.load('en_core_web_sm')

def sentence_segmentation(job_desc):
    """
    This function return a list of sentences for a job description
    """
    doc = nlp(job_desc)
    return [sent for sent in doc.sents]


def get_paras(sents, skills_list, limit = 128):
    '''
    Converts a list of sentences to a list of paragraphs (so that we could limit the number of API calls to some extent)
    '''
    num_token = 0
    paragraphs = []
    sub_skills = []
    para = ''
    for sent in sents:
        sent = sent.text
        num_token += len(sent.split())
        if num_token >= limit:
            paragraphs.append(para)
            sub_skills.append(', '.join([i for i in skills_list if i in para]))
            para = ''
            num_token = 0
        para += sent
    paragraphs.append(para)
    sub_skills.append(', '.join([i for i in skills_list if i in para]))
    return paragraphs, sub_skills

# %%
paras_list = []
skills_list = []
job_id = []
i = 0
for job, skills in tqdm(zip(df['job'], df['filtered_skills'])):
    sents = sentence_segmentation(job)
    skills_list_temp = [i.strip() for i in skills.split(',')]
    paras, skill = get_paras(sents, skills_list_temp, limit = 128)
    paras_list.extend(paras)
    skills_list.extend(skill)
    job_id.extend([i for j in range(len(skill))])
    i+=1
# Out:
# 1842it [02:25, 12.70it/s]

# %%
df_split = pd.DataFrame({'job_id': job_id, 'job_segment':paras_list, 'skills':skills_list})
df_split
# Out:
#       job_id                                        job_segment  \
# 0          0  SummaryThe Database Developer is part of the C...
# 1          0  Perform database security administration.Ensur...
# 2          0  Education And/Or Experience, Certifications, R...
# 3          0  Physical DemandsWhile performing the duties of...
# 4          0  CEMCO, LLC, is the premier manufacturer of ste...
# ...      ...                                                ...
# 6686    1840  Sr. Full Stack DeveloperWelcome to Beaker & Wr...
# 6687    1840  We need a full-stack developer who is a self-s...
# 6688    1840  The desired developer will head development an...
# 6689    1841  Become part of one of a large, high-performing...
# 6690    1841  What should you have?4 Years working in a tech...
#
#                                         skills
# 0        CEMCO, C#, database performance, .Net
# 1                                     C#, .Net
# 2     teamwork, Project management, SQL, T-SQL
# 3                close vision, distance vision
# 4                                   CEMCO, LLC
# ...                                        ...
# 6686
# 6687
# 6688                   HTML, Wordpress, Python
# 6689                                     CI/CD
# 6690                             CI/CD, Python
#
# [6691 rows x 3 columns]

# %%
df.to_csv('Data/GPT-3_data_split_into_128_word_paragraphs.csv')
